# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline


df = pd.read_csv('Violence.csv')
df.head(5)
# Out:
#   CASE_NUMBER                    DATE                  BLOCK    PRIMARY_TYPE  \
# 0    HZ100096  01/01/2016 02:04:00 AM    4600  S ST LAWRENCE  FATAL SHOOTING
# 1    HZ100342  01/01/2016 06:39:00 AM  1900  W GARFIELD BLVD  FATAL SHOOTING
# 2    HZ101042  01/01/2016 10:06:00 PM    6100  S SANGAMON ST  FATAL SHOOTING
# 3    HZ101842  01/02/2016 04:40:00 PM   6300  S STONY ISLAND  FATAL SHOOTING
# 4    HZ103309  01/04/2016 08:22:00 AM     400  N CENTRAL AVE  FATAL SHOOTING
#
#         UNIQUE_ID  ZIP_CODE  WARD   COMMUNITY_AREA  \
# 0  HOM-HZ100096-1     60653     4  GRAND BOULEVARD
# 1  HOM-HZ100342-1     60609    16         NEW CITY
# 2  HOM-HZ101042-1     60621    16        ENGLEWOOD
# 3  HOM-HZ101842-1     60637    20         WOODLAWN
# 4  HOM-HZ103309-1     60644    37           AUSTIN
#
#    STREET OUTREACH ORGANIZATION  AREA  ...  FBI_CD  \
# 0                          None     1  ...     01A
# 1                 PBMR New City     1  ...     01A
# 2  TADC Englewood | READI 60621     1  ...     01A
# 3     Project H.O.O.D. Woodlawn     1  ...     01A
# 4     READI 60644 | INVC Austin     4  ...     01A
#
#                               FBI_DESCR IUCR_CD       IUCR_SECONDARY MONTH  \
# 0  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110  FIRST DEGREE MURDER     1
# 1  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110  FIRST DEGREE MURDER     1
# 2  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110  FIRST DEGREE MURDER     1
# 3  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110  FIRST DEGREE MURDER     1
# 4  HOMICIDE - 1ST OR 2ND DEGREE (INDEX)    0110  FIRST DEGREE MURDER     1
#
#   DAY_OF_WEEK HOUR   LATITUDE  LONGITUDE  \
# 0           6    2  41.810127 -87.611604
# 1           6    6  41.794218 -87.673175
# 2           6   22  41.782338 -87.647905
# 3           7   16  41.780618 -87.586165
# 4           2    8  41.888383 -87.765249
#
#                                    LOCATION
# 0  POINT (-87.611604058699 41.810126904142)
# 1   POINT (-87.67317465388 41.794218345858)
# 2   POINT (-87.64790465388 41.782338345858)
# 3   POINT (-87.58616465388 41.780618345858)
# 4  POINT (-87.765249058699 41.888383095858)
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (21812, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21812 entries, 0 to 21811
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CASE_NUMBER                   21812 non-null  object
#  1   DATE                          21812 non-null  object
#  2   BLOCK                         21812 non-null  object
#  3   PRIMARY_TYPE                  21812 non-null  object
#  4   UNIQUE_ID                     21812 non-null  object
#  5   ZIP_CODE                      21812 non-null  int64
#  6   WARD                          21812 non-null  int64
#  7   COMMUNITY_AREA                21812 non-null  object
#  8   STREET OUTREACH ORGANIZATION  21812 non-null  object
#  9   AREA                          21812 non-null  int64
#  10  DISTRICT                      21812 non-null  int64
#  11  BEAT                          21812 non-null  int64
#  12  AGE                           21550 non-null  object
#  13  SEX                           21605 non-null  object
#  14  RACE                          21605 non-null  object
#  15  FBI_CD                        21812 non-null  object
#  16  FBI_DESCR                     21812 non-null  object
#  17  IUCR_CD                       21812 non-null  object
#  18  IUCR_SECONDARY                21812 non-null  object
#  19  MONTH                         21812 non-null  int64
#  20  DAY_OF_WEEK                   21812 non-null  int64
#  21  HOUR                          21812 non-null  int64
#  22  LATITUDE                      21812 non-null  float64
#  23  LONGITUDE                     21812 non-null  float64
#  24  LOCATION                      21812 non-null  object
# dtypes: float64(2), int64(8), object(15)
# memory usage: 4.2+ MB

# %%
df.describe()
# Out:
#            ZIP_CODE          WARD          AREA      DISTRICT          BEAT  \
# count  21812.000000  21812.000000  21812.000000  21812.000000  21812.000000
# mean   60630.246928     20.561388      2.623877      9.951220   1018.408307
# std       22.007978     11.017371      1.389328      5.867057    587.661843
# min    60601.000000      1.000000      1.000000      1.000000    111.000000
# 25%    60620.000000     10.000000      1.000000      6.000000    612.000000
# 50%    60624.000000     21.000000      2.000000      9.000000    933.000000
# 75%    60639.000000     28.000000      4.000000     12.000000   1223.000000
# max    60827.000000     50.000000      5.000000     25.000000   2535.000000
#
#               MONTH   DAY_OF_WEEK          HOUR      LATITUDE     LONGITUDE
# count  21812.000000  21812.000000  21812.000000  21812.000000  21812.000000
# mean       6.708830      3.964102     13.027645     41.819089    -87.672516
# std        3.026102      2.176130      7.834735      0.076062      0.056448
# min        1.000000      1.000000      0.000000     41.644227    -87.883375
# 25%        5.000000      2.000000      4.000000     41.760018    -87.718269
# 50%        7.000000      4.000000     15.000000     41.812503    -87.671133
# 75%        9.000000      6.000000     20.000000     41.880387    -87.628030
# max       12.000000      7.000000     23.000000     42.022903    -87.525879

# %%
df.isnull().sum()
# Out:
# CASE_NUMBER                       0
# DATE                              0
# BLOCK                             0
# PRIMARY_TYPE                      0
# UNIQUE_ID                         0
# ZIP_CODE                          0
# WARD                              0
# COMMUNITY_AREA                    0
# STREET OUTREACH ORGANIZATION      0
# AREA                              0
# DISTRICT                          0
# BEAT                              0
# AGE                             262
# SEX                             207
# RACE                            207
# FBI_CD                            0
# FBI_DESCR                         0
# IUCR_CD                           0
# IUCR_SECONDARY                    0
# MONTH                             0
# DAY_OF_WEEK                       0
# HOUR                              0
# LATITUDE                          0
# LONGITUDE                         0
# LOCATION                          0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
dup = df.duplicated()
dup.sum()
# Out:
# 0

# %%
df.corr()
# Out:
#              ZIP_CODE      WARD      AREA  DISTRICT      BEAT     MONTH  \
# ZIP_CODE     1.000000  0.070903  0.064997  0.094357  0.094760 -0.002537
# WARD         0.070903  1.000000  0.620900  0.675290  0.673688  0.015262
# AREA         0.064997  0.620900  1.000000  0.640309  0.639476  0.006731
# DISTRICT     0.094357  0.675290  0.640309  1.000000  0.999906  0.001170
# BEAT         0.094760  0.673688  0.639476  0.999906  1.000000  0.001140
# MONTH       -0.002537  0.015262  0.006731  0.001170  0.001140  1.000000
# DAY_OF_WEEK -0.003514  0.000795  0.002752  0.011541  0.011606  0.000111
# HOUR         0.034497 -0.031819 -0.051898 -0.036524 -0.036478 -0.006297
# LATITUDE    -0.052192  0.590923  0.734005  0.614043  0.612330 -0.003052
# LONGITUDE   -0.075464 -0.644303 -0.704867 -0.643071 -0.641706 -0.010753
#
#              DAY_OF_WEEK      HOUR  LATITUDE  LONGITUDE
# ZIP_CODE       -0.003514  0.034497 -0.052192  -0.075464
# WARD            0.000795 -0.031819  0.590923  -0.644303
# AREA            0.002752 -0.051898  0.734005  -0.704867
# DISTRICT        0.011541 -0.036524  0.614043  -0.643071
# BEAT            0.011606 -0.036478  0.612330  -0.641706
# MONTH           0.000111 -0.006297 -0.003052  -0.010753
# DAY_OF_WEEK     1.000000  0.061823 -0.009285   0.001626
# HOUR            0.061823  1.000000 -0.062877   0.021470
# LATITUDE       -0.009285 -0.062877  1.000000  -0.706054
# LONGITUDE       0.001626  0.021470 -0.706054   1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.groupby('PRIMARY_TYPE')['ZIP_CODE'].count().sort_index()
# Out:
# PRIMARY_TYPE
# FATAL SHOOTING            3566
# NON-FATAL SHOOTING       17833
# NON-SHOOTING HOMICIDE      413
# Name: ZIP_CODE, dtype: int64

# %%
pd.plotting.scatter_matrix(df, figsize=(25,25))
plt.show()
